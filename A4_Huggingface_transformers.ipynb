# %% [markdown]
# ### Assignment 4: Hugging Face Transformers

# %% [markdown]
# # Tasks
# #### Fine-Tune a Simple Transformer Model for Text Classification
# ## Objective:
# Fine-tune a simple Transformer-based model (e.g., BERT, DistilBERT, or RoBERTa) for a text classification task.
#
# ## Instructions:
#     1. Load dataset: Choose a classification dataset (e.g., IMDb for sentiment analysis, AG News for topic classification).
#     2. Tokenization: Tokenize text using AutoTokenizer, ensuring proper padding and truncation.
#     3. Load pretrained model: Use AutoModelForSequenceClassification and fine-tune it on the dataset.
#     4. Train model: Use the Hugging Face Trainer API for training with appropriate hyperparameters.
#     5. Evaluation: Measure accuracy, precision, recall, and F1-score.
#     6. Analysis: Compare predictions before and after fine-tuning, and discuss key observations.
# ###  Bonus: Try different Transformer models, optimize training with early stopping, or visualize attention scores.

# %%
# !pip install transformers datasets evaluate torch

# %% [markdown]
# ### Installed Libraries
#
# * transformers: for pretrained models
# * datasets: for loading built-in datasets
# * evaluate: for evaluation metrics (accuracy, F1, etc.)
# * torch: for PyTorch backend

# %%
# !pip install transformers datasets evaluate torch

# %% [markdown]
# ### Import Libraries
#
# These are the main libraries you’ll use for tokenization, model loading, training, evaluation, and inference.

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import TrainingArguments, Trainer, pipeline
import evaluate
import numpy as np

# %% [markdown]
# ### Load Datasat

# %% [markdown]
# ### Tokenization

# %% [markdown]
# ### Load pretrained model

# %% [markdown]
# ### Train model

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ### Analysis

# %% [markdown]
# ## Deliverable
# Please strcitly adhere to the submission guidleines, i.e.,  submit the .ipynb file with complete code.
